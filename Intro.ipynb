# %% [markdown]
# # Introduction to python

# %% [markdown]
# ## Input to output

# %%
print("hello world")

# %%
print("a"),("b"),("c")

# %%
input()

# %%
input("please enter your name")

# %% [markdown]
# ## Variables

# %%
a="This is a sentence."
b ="This is a another sentence."

# %%
print("a",a)
print("b",b)
print("a,b",a,b)

# %%
ABCD=a>""<b

# %%
print("ABCD)",ABCD)

# %% [markdown]
# ## Arithmetic and Boolean Operators

# %%
print(\[8],"+",l[2],"=",l[0]+l[2])
